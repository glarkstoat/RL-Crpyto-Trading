# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pprint
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider

sns.set_style('darkgrid')
sns.set(color_codes=True)
sns.set_context('paper')

# %%
df = pd.read_csv("Poloniex_BTCUSDT_d.csv")

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2817 entries, 0 to 2816
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix         2817 non-null   int64
#  1   date         2817 non-null   object
#  2   symbol       2817 non-null   object
#  3   open         2817 non-null   float64
#  4   high         2817 non-null   float64
#  5   low          2817 non-null   float64
#  6   close        2817 non-null   float64
#  7   Volume BTC   2817 non-null   float64
#  8   Volume USDT  2817 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 198.2+ KB
#             unix                 date    symbol          open          high  \
# 0     1639612800  2021-12-16 00:00:00  BTC/USDT  48861.439144  48932.042256
# 1     1639526400  2021-12-15 00:00:00  BTC/USDT  48366.946618  49474.000000
# 2     1639440000  2021-12-14 00:00:00  BTC/USDT  46714.546820  48630.510469
# 3     1639353600  2021-12-13 00:00:00  BTC/USDT  50065.797814  50194.299970
# 4     1639267200  2021-12-12 00:00:00  BTC/USDT  49369.680202  50764.827948
# ...          ...                  ...       ...           ...           ...
# 2812  1422835200  2015-02-02 00:00:00  BTC/USDT    229.990000    241.370000
# 2813  1422748800  2015-02-01 00:00:00  BTC/USDT    236.000000    236.000000
# 2814  1422662400  2015-01-31 00:00:00  BTC/USDT    236.760000    238.000000
# 2815  1422576000  2015-01-30 00:00:00  BTC/USDT    241.000000    254.750000
# 2816  1422489600  2015-01-29 00:00:00  BTC/USDT    235.000000    242.000000
#
#                low         close    Volume BTC  Volume USDT
# 0     48743.672996  48920.940331  2.020959e+05     4.136517
# 1     46552.798493  48871.211115  2.605109e+07   540.137467
# 2     46307.491826  48374.877049  2.018067e+07   427.667960
# 3     45750.000000  46730.538241  2.721620e+07   570.629735
# 4     48650.643443  50073.307558  1.724996e+07   347.390672
# ...            ...           ...           ...          ...
# 2812    229.990000    241.370000  6.877100e+02     2.908000
# 2813    227.250000    229.990000  4.253300e+02     1.863000
# 2814    228.970000    236.000000  1.394500e+02     0.594500
# 2815    236.110000    236.760000  6.011000e+02     2.503000
# 2816    232.000000    241.000000  6.929600e+02     2.902000
#
# [2817 rows x 9 columns]

# %%
df.plot(x="date", y="open", linewidth=.1)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df["symbol"].unique()
# Out:
# array(['BTC/USDT'], dtype=object)
